# %% [markdown]
# # Mt. Everest Expeditions
# Bronze Layer Processing

# %%
df = spark.read.format("csv").option("header","true").load("Files/*.csv")
# df now is a Spark DataFrame containing CSV data from "Files/*.csv".
# Out:
# StatementMeta(, d2369581-c4dc-47b5-9ee5-35a22d61d4c2, 5, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, d2369581-c4dc-47b5-9ee5-35a22d61d4c2, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7dbb3417-28d0-4593-892d-be3824c725aa)
